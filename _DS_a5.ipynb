# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavandunghav/DataScience_lab-/blob/main/_DS_a5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
1.	Implement	logistic regression using Python/R to	perform classification	on Social Network Ads.csv dataset.
2.	Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall
             on the given dataset.


'''
# Out:
# '\n1.\tImplement\tlogistic regression using Python/R to\tperform classification\ton Social Network Ads.csv dataset.\n2.\tCompute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall\n             on the given dataset.\n\n\n'

# %%
###Importing the necessary libraries



import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/DATASETS/Social_Network_Ads.csv")


data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder



data['Gender']=LabelEncoder().fit_transform(data['Gender'])



data   ##Here 1 is Male and 0 is Female
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler


data=pd.DataFrame(MinMaxScaler().fit_transform(data),columns=data.columns)


data
# Out:
#       User ID  Gender       Age  EstimatedSalary  Purchased
# 0    0.232636     1.0  0.023810         0.029630        0.0
# 1    0.982732     1.0  0.404762         0.037037        0.0
# 2    0.409926     0.0  0.190476         0.207407        0.0
# 3    0.147083     0.0  0.214286         0.311111        0.0
# 4    0.954801     1.0  0.023810         0.451852        0.0
# ..        ...     ...       ...              ...        ...
# 395  0.503623     0.0  0.666667         0.192593        1.0
# 396  0.560787     1.0  0.785714         0.059259        1.0
# 397  0.352477     0.0  0.761905         0.037037        1.0
# 398  0.757720     1.0  0.428571         0.133333        0.0
# 399  0.110048     0.0  0.738095         0.155556        1.0
#
# [400 rows x 5 columns]

# %%
y=data['Purchased']
x=data.drop('Purchased',axis=1)

# %%
##Dividing the data into the into training and the testing data

from sklearn.model_selection import train_test_split


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,y_train.shape
# Out:
# ((320, 4), (320,))

# %%
##Building te model



from  sklearn.linear_model import LogisticRegression



model=LogisticRegression()



model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
##Making the prediction



y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8

# %%
y_pred=model.predict(x_test)

# %%
##Evaluation

from sklearn.metrics import precision_score ,recall_score,confusion_matrix,f1_score

# %%
print(f"The precision_score for this modle is {precision_score(y_pred,y_test)}")
print(f"The Recall_score for this model is {recall_score(y_pred,y_test)}")
print(f"The confusion_matrix for this model is {confusion_matrix(y_pred,y_test)}")
print(f"The f1_score  for this model  is {f1_score(y_pred,y_test)}")
# Out:
# The precision_score for this modle is 0.625
# The Recall_score for this model is 0.6818181818181818
# The confusion_matrix for this model is [[49  9]
#  [ 7 15]]
# The f1_score  for this model  is 0.6521739130434783
